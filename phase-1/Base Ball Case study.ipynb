# %% [markdown]
# # Base Ball Case Studey

# %% [markdown]
# we import some important libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("baseball.csv")
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # [EDA]

# %% [markdown]
# Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.shape
# Out:
# (30, 17)

# %%
df.keys()
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df['W'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
df.describe().T
# Out:
#      count         mean         std      min        25%       50%      75%  \
# W     30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R     30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB    30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H     30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# 2B    30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# 3B    30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR    30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB    30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO    30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB    30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA    30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ...

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
#cheking the pairwise relation the dataset
sns.pairplot(df)

# %% [markdown]
# here we can see relationship beetween all the featues and the lables

# %%
#wins ploting distrubution wise
plt.hist(df['W'])
plt.xlabel('Wins')
plt.title('DistrIbution of wins')
# Out:
# Text(0.5, 1.0, 'DistrIbution of wins')

# %%
#checking the corrlation of lable and features
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
#cheking the corrlation by heatmap
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),linewidths=0.5,annot=True)
# Out:
# <AxesSubplot:>

# %%
#visualizing correlation beetween features and label
plt.figure(figsize=(20,8))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title('Correlation between label and features using Bar plot',fontsize=18)
plt.show()

# %% [markdown]
# here we can see that features cg and h has very low correlation,
# so we can droped these are both column H and CG.

# %%
df.plot(kind="box", subplots=True, figsize=(15,8))
# Out:
# W         AxesSubplot(0.125,0.125;0.0383663x0.755)
# R       AxesSubplot(0.17104,0.125;0.0383663x0.755)
# AB     AxesSubplot(0.217079,0.125;0.0383663x0.755)
# H      AxesSubplot(0.263119,0.125;0.0383663x0.755)
# 2B     AxesSubplot(0.309158,0.125;0.0383663x0.755)
# 3B     AxesSubplot(0.355198,0.125;0.0383663x0.755)
# HR     AxesSubplot(0.401238,0.125;0.0383663x0.755)
# BB     AxesSubplot(0.447277,0.125;0.0383663x0.755)
# SO     AxesSubplot(0.493317,0.125;0.0383663x0.755)
# SB     AxesSubplot(0.539356,0.125;0.0383663x0.755)
# RA     AxesSubplot(0.585396,0.125;0.0383663x0.755)
# ER     AxesSubplot(0.631436,0.125;0.0383663x0.755)
# ERA    AxesSubplot(0.677475,0.125;0.0383663x0.755)
# CG     AxesSubplot(0.723515,0.125;0.0383663x0.755)
# SHO    AxesSubplot(0.769554,0.125;0.0383663x0.755)
# SV     AxesSubplot(0.815594,0.125;0.0383663x0.755)
# E      AxesSubplot(0.861634,0.125;0.0383663x0.755)
# dtype: object

# %% [markdown]
# here we can see boxplot and we can understand some of the values varirablesuch as SHO,ERA,EV,R.

# %%
plt.scatter(df.iloc[:,0],df.iloc[:,4])

# %%
plt.scatter(df.iloc[:,0],df.iloc[:,1])

# %% [markdown]
# heare we can see above some positive relationship.

# %%
df['W'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['R'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['HR'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # REMOVE OUTLIERS
# Now we are going to remove the outliers by using Z-score

# %%
from scipy.stats import zscore
z_score=abs(zscore(df))
print(df.shape)
# Out:
# (30, 17)

# %%
df1=df.loc[(z_score<3).all(axis=1)]
df1.shape
# Out:
# (29, 17)

# %% [markdown]
# we have seen dataset is changed becoz some outliers have removed the new dataset is to (29,17)

# %%
df1.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# we will be managed them to maintained some  skewness of our dataset,as may be we have seen some attributes with skewness.

# %%
for col in df1.columns:
    if df1.skew().loc[col]>0.55:
        df1[col]=np.log1p(df1[col])
df1.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.275681
# SHO    0.526943
# SV     0.109983
# E      0.586101
# dtype: float64

# %%
df1["R"].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# we can seen above is not a big diffrence

# %%
df1["W"].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1["E"].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1["H"].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model Building

# %% [markdown]
# now divided dataset in target and input variables

# %%
 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# defining x, y 
dx = df1.drop(columns=["W"])
y = df1[["W"]]

# Scaling x,y
x=sc.fit_transform(dx)
x=pd.DataFrame(x,columns=dx.columns)

# %%
from sklearn.linear_model import LinearRegression,Lasso, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor

# %% [markdown]
# defined all tbe Models

# %%
lr=LinearRegression()
knn=KNeighborsRegressor()
ls=Lasso()
rd=Ridge()
rf=RandomForestRegressor()
gbr=GradientBoostingRegressor()
ada=AdaBoostRegressor()

models=[]
models.append(("LinearRegression",lr))
models.append(("KNeighborsRegressor",knn))
models.append(("Lasso",ls))
models.append(("Ridge",rd))
models.append(("RandomForestRegressor",rf))
models.append(("GradientBoostingRegressor",gbr))
models.append(("AdaBoostRegressor",ada))

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


Model=[]
RState=[]
score=[]

for name, model in models:
    print("===========",name,"===========")
    print("\n")
    Model.append(name)
    max_r2_score=0.0
    for r_state in range (42,101):
        x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=0.17,random_state=r_state)
        model.fit(x_train,y_train)
        y_pred = model.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        if r2_scr>max_r2_score:
            max_r2_score=r2_scr
            final_r_state=r_state
    print("Final Random State is:", final_r_state)
    print("\n")
    RState.append(final_r_state*1)
    print("R2 score : ", max_r2_score)
    print("\n")
    score.append(max_r2_score*100)
    print("\n")
# Out:
# =========== LinearRegression ===========
#
#
# Final Random State is: 67
#
#
# R2 score :  0.9222372872932246
#
#
#
#
# =========== KNeighborsRegressor ===========
#
#
# Final Random State is: 71
#
#
# R2 score :  0.8503846153846147
#
#
#
#
# =========== Lasso ===========
#
#
# Final Random State is: 68
#
#
# R2 score :  0.9877515977312986
#
#
#
#
# =========== Ridge ===========
#
#
# Final Random State is: 47
#
#
# R2 score :  0.9607868243596891
#
#
#
#
# =========== RandomForestRegressor ===========
#
#
# Final Random State is: 68
#
#
# R2 score :  0.7975884146341465
#
#
#
#
# =========== GradientBoostingRegressor ===========
#
#
# Final Random State is: 52
#
#
# R2 score :  0.8562719535297681
#
#
#
#
# =========== AdaBoostRegressor ===========
#
#
# Final Random State is: 48
#
#
# R2 score :  0.8004416532799928

# %%
ovr_all_result=pd.DataFrame({"Model":Model,"Random_state":RState,"R2_score":score})
ovr_all_result
# Out:
#                        Model  Random_state   R2_score
# 0           LinearRegression            67  92.223729
# 1        KNeighborsRegressor            71  85.038462
# 2                      Lasso            68  98.775160
# 3                      Ridge            47  96.078682
# 4      RandomForestRegressor            68  79.758841
# 5  GradientBoostingRegressor            52  85.627195
# 6          AdaBoostRegressor            48  80.044165

# %% [markdown]
# We can see above result now we will be see best parameters for lasso model with gridsearchCV, Lasso model is the best model

# %%
from sklearn.model_selection import GridSearchCV

parameters = {"alpha": [0.0001,0.001,0.01,0.09,0.1,1]}
clf=GridSearchCV(ls,parameters, cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'alpha': 1}

# %%
# again we building the model withh best aprameters 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.17, random_state=68)
ls=Lasso(alpha=1).fit(x_train,y_train)
ls_pred = ls.predict(x_test)
print("R2 score : ", r2_score(y_test,ls_pred))
print("RMSE : ",np.sqrt(mean_squared_error(y_test,ls_pred)))
# Out:
# R2 score :  0.9877515977312986
# RMSE :  0.850379721032979

# %%
from sklearn.model_selection import cross_val_score
print("Mean R2 score of Lasso model is:", cross_val_score(ls,x,y,cv=5,scoring="r2").mean())
print("Std of Lasso model is : ",cross_val_score(ls,x,y,cv=5,scoring="r2").mean())
# Out:
# Mean R2 score of Lasso model is: 0.49033824821340943
# Std of Lasso model is :  0.49033824821340943

# %%
print("Actual Wins:\n",y_test)
print("Predicted Wins:\n",ls_pred)
# Out:
# Actual Wins:
#       W
# 20  90
# 28  74
# 29  68
# 26  84
# 2   81
# Predicted Wins:
#  [90.15722372 75.82775867 67.57448062 84.26126321 80.96866146]

# %% [markdown]
# the model is predicting good because we can see above value is good

# %% [markdown]
# # Saving the Model

# %% [markdown]
# saving by Joblib

# %%
import joblib
joblib.dump(ls,"Lasso_Baseball_wins_prediction_obj")
# Out:
# ['Lasso_Baseball_wins_prediction_obj']

# %% [markdown]
# thank you
